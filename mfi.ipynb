# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("mfi.csv")

# %%
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
ds=df.drop(['msisdn','pcircle','pdate'],axis=1)

# %%
ds.head(2)
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0       3055.05       3065.15    220.13    260.13
# 1      1  712.0      12122.00      12124.75   3691.26   3691.26
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0                2.0                0.0              1539              2  ...
# 1               20.0                0.0              5787              1  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# 0            2            12              6.0                 0.0
# 1            1            12             12.0                 0.0
#
#    cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  \
# 0          2.0            12                6                 0.0       29.0
# 1          1.0            12               12                 0.0        0.0
#
#    payback90
# 0       29.0
# 1        0.0
#
# [2 rows x 33 columns]

# %%
ds.dtypes
# Out:
# label                     int64
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# ...

# %%
pd.set_option('display.max_columns', None)
ds.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
ds.drop(['aon','last_rech_date_ma','last_rech_date_da','medianmarechprebal30','cnt_da_rech30','fr_da_rech30','cnt_da_rech90'],axis=1,inplace=True)

# %%
ds.drop(['fr_da_rech90','maxamnt_loans30','cnt_loans90'],axis=1,inplace=True)

# %%
ds.columns
# Out:
# Index(['label', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_loans30', 'amnt_loans30',
#        'medianamnt_loans30', 'amnt_loans90', 'maxamnt_loans90',
#        'medianamnt_loans90', 'payback30', 'payback90'],
#       dtype='object')

# %%
sns.countplot(x='label',data=ds)
plt.show()

# %%
ds.skew()
# Out:
# label                   -2.270254
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# medianamnt_loans30       4.551043
# amnt_loans90             3.150006
# maxamnt_loans90          1.678304
# medianamnt_loans90       4.895720
# payback30                8.310695
# payback90                6.899951
# dtype: float64

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(ds))
z.shape
# Out:
# (209593, 23)

# %%
threshold=3
print(np.where(z<3))
# Out:
# (array([     0,      0,      0, ..., 209592, 209592, 209592], dtype=int64), array([ 0,  1,  2, ..., 20, 21, 22], dtype=int64))

# %%
ds_new=ds[(z<3).all(axis=1)]
print(ds.shape)
print(ds_new.shape)
# Out:
# (209593, 23)
# (169631, 23)

# %% [markdown]
# we can't remove all outlier as there will be loose of large amount of data which is around 22%

# %%
ds.astype(bool).sum(axis=0)
# Out:
# label                   183431
# daily_decr30            205449
# daily_decr90            205530
# rental30                202027
# rental90                202675
# last_rech_amt_ma        188598
# cnt_ma_rech30           181614
# fr_ma_rech30            130910
# sumamnt_ma_rech30       181614
# medianamnt_ma_rech30    181614
# cnt_ma_rech90           188643
# fr_ma_rech90            143840
# sumamnt_ma_rech90       188643
# medianamnt_ma_rech90    188643
# medianmarechprebal90    186202
# cnt_loans30             206334
# amnt_loans30            206334
# medianamnt_loans30       14148
# amnt_loans90            207550
# maxamnt_loans90         207550
# medianamnt_loans90       12169
# payback30               102881
# payback90               113894
# dtype: int64

# %%
y=ds['label']
x=ds.iloc[:,1:]

# %%
y.shape
# Out:
# (209593,)

# %%
x.shape
# Out:
# (209593, 22)

# %%
x.head()
# Out:
#    daily_decr30  daily_decr90  rental30  rental90  last_rech_amt_ma  \
# 0   3055.050000   3065.150000    220.13    260.13              1539
# 1  12122.000000  12124.750000   3691.26   3691.26              5787
# 2   1398.000000   1398.000000    900.13    900.13              1539
# 3     21.228000     21.228000    159.42    159.42               947
# 4    150.619333    150.619333   1098.90   1098.90              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0              2          21.0             3078.0                1539.0
# 1              1           0.0             5787.0                5787.0
# 2              1           0.0             1539.0                1539.0
# 3              0           0.0                0.0                   0.0
# 4              7           2.0            20029.0                2309.0
#
#    cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
import warnings
import joblib
warnings.filterwarnings('ignore')

# %%
lr=LogisticRegression()

# %%
maxr2=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    acc=accuracy_score(y_test,predlr)
    if acc>maxr2:
        maxr2=acc
        maxRS=i
print("Best accuracy is ",maxr2," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.8811826075892999  on Random_state  51

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=51)

# %%
model=[KNeighborsClassifier(),DecisionTreeClassifier(),GaussianNB(),SVC()]
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print("accuracy score of ", m , "is:")
    print(accuracy_score(y_test,predm))
# Out:
# accuracy score of  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform') is:
# 0.8958300200388053
# accuracy score of  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best') is:
# 0.8664556760711218
# accuracy score of  GaussianNB(priors=None, var_smoothing=1e-09) is:
# 0.5481726518019021
# accuracy score of  SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
# ...

# %%
kn=KNeighborsClassifier()
kn.fit(x_train,y_train)
predkn=kn.predict(x_test)
print(accuracy_score(y_test,predkn))
# Out:
# 0.8958300200388053
